# %% [markdown]
# # CIFAR 10
#
# This notebook trains a classifier on CIFAR10 using Tensorflow

# %%
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf
import tensorflow_datasets as tfds
import os
import os.path
import time
import datetime

# %%
# 100 epochs will take ages on CPU, reduce or use GPU
EPOCHS = 150
BATCH_SIZE = 50
LABELS = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]

# %% [markdown]
# ## Load Data

# %%
def unpack(batch):
    return batch["image"], batch["label"]

def normalize_img(image, label):
    return tf.cast(image, tf.float32) / 255., label

# %%
def prepare(batch):
    return (
        {
            "image": tf.cast(batch["image"], tf.float32) / 255.,
            "id": batch["id"],
        },
        batch["label"],
    )

# %%
train_ds, test_ds = tfds.load("cifar10", split=["train", "test"], data_dir="/tmp/tensorflow_datasets")
# Out:
# Downloading and preparing dataset 162.17 MiB (download: 162.17 MiB, generated: 132.40 MiB, total: 294.58 MiB) to /tmp/tensorflow_datasets/cifar10/3.0.2...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Completed...', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Size...', max=1.0, style=ProgressSty…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Extraction completed...', max=1.0, styl…
# HBox(children=(FloatProgress(value=0.0, description='Generating splits...', max=2.0, style=ProgressStyle(descr…
# HBox(children=(FloatProgress(value=0.0, description='Generating train examples...', max=50000.0, style=Progres…
# HBox(children=(FloatProgress(value=0.0, description='Shuffling cifar10-train.tfrecord...', max=50000.0, style=…
# HBox(children=(FloatProgress(value=0.0, description='Generating test examples...', max=10000.0, style=Progress…
# HBox(children=(FloatProgress(value=0.0, description='Shuffling cifar10-test.tfrecord...', max=10000.0, style=P…
# Dataset cifar10 downloaded and prepared to /tmp/tensorflow_datasets/cifar10/3.0.2. Subsequent calls will reuse this data.

# %%
# split off a chunk of training data for validation
val_ds = train_ds.take(1000)
train_ds = train_ds.skip(1000)

train_ds_unshuffle = (
    train_ds
    .batch(BATCH_SIZE)
    .map(prepare)
)
train_ds = (
    train_ds
    .shuffle(buffer_size=8 * BATCH_SIZE)
    .batch(BATCH_SIZE)
    .map(prepare)
)
val_ds = (
    val_ds
    .batch(BATCH_SIZE)
    .map(prepare)
)
test_ds = (
    test_ds
    .batch(BATCH_SIZE)
    .map(prepare)
)

# %%
# visualise examples
batch, labels = next(iter(train_ds))
images = batch["image"].numpy()

fig, axes = plt.subplots(2, ncols=5, figsize=(15, 6))

for i, ax in enumerate(axes.flat):
    ax.imshow(images[i], cmap='binary', interpolation='nearest')
    ax.set_title(LABELS[labels[i]])

# %% [markdown]
# ## Train Model

# %% [markdown]
# ### Defining all test models

# %%
def build_model(name="model"):
    block = tf.keras.Sequential([
        tf.keras.layers.Conv2D(32, 3, activation="relu", padding="same", input_shape=(32, 32, 3)),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Conv2D(32, 3, activation="relu", padding="same"),
        tf.keras.layers.MaxPool2D(),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Conv2D(64, 3, activation="relu", padding="same"),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Conv2D(64, 3, activation="relu", padding="same"),
        tf.keras.layers.MaxPool2D(),
        tf.keras.layers.Dropout(0.3),
        
        tf.keras.layers.Conv2D(128, 3, activation="relu", padding="same"),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Conv2D(128, 3, activation="relu", padding="same"),
        tf.keras.layers.MaxPool2D(),
        tf.keras.layers.Dropout(0.4),
        
        tf.keras.layers.Reshape((2048,)),
        tf.keras.layers.Dense(10)
    ], name=name)
    
    input_ = tf.keras.Input(name="image", shape=(32, 32, 3))
    output = block(input_)
    model = tf.keras.Model(inputs=input_, outputs=output)
    
    model.compile(
        "adam",
        loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=["sparse_categorical_accuracy"])
    
    return model

# %% [markdown]
# Creating a checkpoint path to store model trainig history

# %%
# checkpoint callback
checkpoint_path = "cp_training_cifar_10/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

BATCHES_PER_EPOCH = int(49000/BATCH_SIZE)

# creating a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 verbose=1,
                                                 save_weights_only=True,
                                                 save_freq=5*BATCHES_PER_EPOCH)

# %% [markdown]
# Instantiating a CNN model on the cifar-10 dataset

# %%
model = build_model()
model.summary()

# save model weights
model.save_weights(checkpoint_path.format(epoch=0))
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# image (InputLayer)           [(None, 32, 32, 3)]       0
# _________________________________________________________________
# model (Sequential)           (None, 10)                308394
# =================================================================
# Total params: 308,394
# Trainable params: 307,946
# Non-trainable params: 448
# _________________________________________________________________

# %% [markdown]
# ### Training model

# %%
start = time.time()
history = model.fit(train_ds, 
                    epochs=EPOCHS, 
                    validation_data=val_ds,
                    verbose=1,
                    callbacks=[cp_callback, tf.keras.callbacks.EarlyStopping(restore_best_weights=True, patience=15)])
end = time.time()
print("Total time:", datetime.timedelta(seconds=end - start))
# Out:
# Epoch 1/150
# 980/980 [==============================] - 6s 6ms/step - loss: 0.3166 - sparse_categorical_accuracy: 0.8873 - val_loss: 0.5844 - val_sparse_categorical_accuracy: 0.8290
# Epoch 2/150
# 707/980 [====================>.........] - ETA: 1s - loss: 0.3195 - sparse_categorical_accuracy: 0.8880
# Epoch 00002: saving model to cp_training_cifar_10/cp-0002.ckpt
# 980/980 [==============================] - 6s 6ms/step - loss: 0.3183 - sparse_categorical_accuracy: 0.8885 - val_loss: 0.5837 - val_sparse_categorical_accuracy: 0.8210
# Epoch 3/150
# 980/980 [==============================] - 6s 6ms/step - loss: 0.3010 - sparse_categorical_accuracy: 0.8941 - val_loss: 0.5774 - val_sparse_categorical_accuracy: 0.8160
# Epoch 4/150
# 980/980 [==============================] - 6s 6ms/step - loss: 0.2917 - sparse_categorical_accuracy: 0.8981 - val_loss: 0.5977 - val_sparse_categorical_accuracy: 0.8160
# Epoch 5/150
# 980/980 [==============================] - 6s 6ms/step - loss: 0.2911 - sparse_categorical_accuracy: 0.8971 - val_loss: 0.5390 - val_sparse_categorical_accuracy: 0.8330
# Epoch 6/150
# 980/980 [==============================] - 6s 6ms/step - loss: 0.2848 - sparse_categorical_accuracy: 0.8984 - val_loss: 0.5144 - val_sparse_categorical_accuracy: 0.8340
# Epoch 7/150
# 708/980 [====================>.........] - ETA: 1s - loss: 0.2872 - sparse_categorical_accuracy: 0.8979
# Epoch 00007: saving model to cp_training_cifar_10/cp-0007.ckpt
# 980/980 [==============================] - 6s 6ms/step - loss: 0.2860 - sparse_categorical_accuracy: 0.8982 - val_loss: 0.4916 - val_sparse_categorical_accuracy: 0.8360
# Epoch 8/150
# 980/980 [==============================] - 6s 6ms/step - loss: 0.2753 - sparse_categorical_accuracy: 0.9020 - val_loss: 0.5449 - val_sparse_categorical_accuracy: 0.8480
# Epoch 9/150
# 980/980 [==============================] - 6s 6ms/step - loss: 0.2716 - sparse_categorical_accuracy: 0.9019 - val_loss: 0.5598 - val_sparse_categorical_accuracy: 0.8350
# Epoch 10/150
# 980/980 [==============================] - 6s 6ms/step - loss: 0.2687 - sparse_categorical_accuracy: 0.9036 - val_loss: 0.4751 - val_sparse_categorical_accuracy: 0.8590
# Epoch 11/150
# 980/980 [==============================] - 6s 6ms/step - loss: 0.2608 - sparse_categorical_accuracy: 0.9061 - val_loss: 0.5082 - val_sparse_categorical_accuracy: 0.8490
# Epoch 12/150
# 706/980 [====================>.........] - ETA: 1s - loss: 0.2650 - sparse_categorical_accuracy: 0.9059
# Epoch 00012: saving model to cp_training_cifar_10/cp-0012.ckpt
# 980/980 [==============================] - 6s 6ms/step - loss: 0.2641 - sparse_categorical_accuracy: 0.9063 - val_loss: 0.5205 - val_sparse_categorical_accuracy: 0.8300
# Epoch 13/150
# 980/980 [==============================] - 6s 6ms/step - loss: 0.2560 - sparse_categorical_accuracy: 0.9084 - val_loss: 0.5596 - val_sparse_categorical_accuracy: 0.8350
# Epoch 14/150
# 980/980 [==============================] - 6s 6ms/step - loss: 0.2553 - sparse_categorical_accuracy: 0.9094 - val_loss: 0.4972 - val_sparse_categorical_accuracy: 0.8340
# Epoch 15/150
# 980/980 [==============================] - 6s 6ms/step - loss: 0.2484 - sparse_categorical_accuracy: 0.9120 - val_loss: 0.5004 - val_sparse_categorical_accuracy: 0.8350
# Epoch 16/150
# 980/980 [==============================] - 6s 6ms/step - loss: 0.2460 - sparse_categorical_accuracy: 0.9112 - val_loss: 0.5146 - val_sparse_categorical_accuracy: 0.8520
# Epoch 17/150
# 708/980 [====================>.........] - ETA: 1s - loss: 0.2459 - sparse_categorical_accuracy: 0.9126
# Epoch 00017: saving model to cp_training_cifar_10/cp-0017.ckpt
# 980/980 [==============================] - 6s 6ms/step - loss: 0.2468 - sparse_categorical_accuracy: 0.9120 - val_loss: 0.4911 - val_sparse_categorical_accuracy: 0.8470
# Epoch 18/150
# 980/980 [==============================] - 6s 6ms/step - loss: 0.2404 - sparse_categorical_accuracy: 0.9148 - val_loss: 0.5384 - val_sparse_categorical_accuracy: 0.8410
# Epoch 19/150
# 980/980 [==============================] - 6s 6ms/step - loss: 0.2383 - sparse_categorical_accuracy: 0.9152 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.7870
# Epoch 20/150
# 980/980 [==============================] - 6s 6ms/step - loss: 0.2401 - sparse_categorical_accuracy: 0.9153 - val_loss: 0.4485 - val_sparse_categorical_accuracy: 0.8580
# Epoch 21/150
# 980/980 [==============================] - 6s 6ms/step - loss: 0.2322 - sparse_categorical_accuracy: 0.9174 - val_loss: 0.5175 - val_sparse_categorical_accuracy: 0.8550
# Epoch 22/150
# 700/980 [====================>.........] - ETA: 1s - loss: 0.2284 - sparse_categorical_accuracy: 0.9193
# Epoch 00022: saving model to cp_training_cifar_10/cp-0022.ckpt
# 980/980 [==============================] - 6s 6ms/step - loss: 0.2283 - sparse_categorical_accuracy: 0.9197 - val_loss: 0.4784 - val_sparse_categorical_accuracy: 0.8510
# Epoch 23/150
# 980/980 [==============================] - 6s 6ms/step - loss: 0.2293 - sparse_categorical_accuracy: 0.9176 - val_loss: 0.6110 - val_sparse_categorical_accuracy: 0.8320
# Epoch 24/150
# 980/980 [==============================] - 6s 6ms/step - loss: 0.2242 - sparse_categorical_accuracy: 0.9209 - val_loss: 0.5039 - val_sparse_categorical_accuracy: 0.8530
# Epoch 25/150
# 980/980 [==============================] - 6s 6ms/step - loss: 0.2185 - sparse_categorical_accuracy: 0.9229 - val_loss: 0.4696 - val_sparse_categorical_accuracy: 0.8590
# Epoch 26/150
# 980/980 [==============================] - 6s 6ms/step - loss: 0.2272 - sparse_categorical_accuracy: 0.9192 - val_loss: 0.5359 - val_sparse_categorical_accuracy: 0.8490
# Epoch 27/150
# 708/980 [====================>.........] - ETA: 1s - loss: 0.2220 - sparse_categorical_accuracy: 0.9219
# Epoch 00027: saving model to cp_training_cifar_10/cp-0027.ckpt
# 980/980 [==============================] - 6s 6ms/step - loss: 0.2200 - sparse_categorical_accuracy: 0.9215 - val_loss: 0.5303 - val_sparse_categorical_accuracy: 0.8380
# Epoch 28/150
# 980/980 [==============================] - 6s 6ms/step - loss: 0.2191 - sparse_categorical_accuracy: 0.9220 - val_loss: 0.5415 - val_sparse_categorical_accuracy: 0.8420
# Epoch 29/150
# 980/980 [==============================] - 6s 6ms/step - loss: 0.2193 - sparse_categorical_accuracy: 0.9224 - val_loss: 0.5543 - val_sparse_categorical_accuracy: 0.8500
# Epoch 30/150
# 980/980 [==============================] - 6s 6ms/step - loss: 0.2174 - sparse_categorical_accuracy: 0.9224 - val_loss: 0.5442 - val_sparse_categorical_accuracy: 0.8160
# Epoch 31/150
# 980/980 [==============================] - 6s 6ms/step - loss: 0.2111 - sparse_categorical_accuracy: 0.9246 - val_loss: 0.5994 - val_sparse_categorical_accuracy: 0.8280
# Epoch 32/150
# 700/980 [====================>.........] - ETA: 1s - loss: 0.2103 - sparse_categorical_accuracy: 0.9244
# Epoch 00032: saving model to cp_training_cifar_10/cp-0032.ckpt
# 980/980 [==============================] - 6s 6ms/step - loss: 0.2101 - sparse_categorical_accuracy: 0.9245 - val_loss: 0.5570 - val_sparse_categorical_accuracy: 0.8360
# Epoch 33/150
# 980/980 [==============================] - 6s 6ms/step - loss: 0.2134 - sparse_categorical_accuracy: 0.9237 - val_loss: 0.5734 - val_sparse_categorical_accuracy: 0.8490
# Epoch 34/150
# 980/980 [==============================] - 6s 6ms/step - loss: 0.2091 - sparse_categorical_accuracy: 0.9260 - val_loss: 0.5314 - val_sparse_categorical_accuracy: 0.8490
# Epoch 35/150
# 980/980 [==============================] - 6s 6ms/step - loss: 0.2061 - sparse_categorical_accuracy: 0.9265 - val_loss: 0.5276 - val_sparse_categorical_accuracy: 0.8440
# Total time: 0:03:16.073982

# %% [markdown]
# ## Results

# %% [markdown]
# Summary of the model performance. The defined methods can be used to compare multiple models.

# %%
# model plotter
def plot_model_results(history, clr, i="_alt"):
    ax[0].plot(history.history["loss"], "{}".format(clr), label="M{} Train loss".format(i), linewidth=2)
    ax[0].plot(history.history["val_loss"], "{}--".format(clr), label="M{} Val loss".format(i), linewidth=2)
    ax[1].plot(history.history["sparse_categorical_accuracy"], "{}".format(clr), label="M{} Train accuracy".format(i), linewidth=1.5)
    ax[1].plot(history.history["val_sparse_categorical_accuracy"], "{}--".format(clr), label="M{} Val accuracy".format(i), linewidth=1.5)
    ax[0].set_xlabel("$Epochs$", fontsize=16), ax[1].set_xlabel("$Epochs$", fontsize=16)
    ax[0].set_ylabel("$Loss$", fontsize=16), ax[1].set_ylabel("$Accuracy$", fontsize=16)
    ax[0].set_title("Loss", fontsize=18), ax[1].set_title("Accuracy", fontsize=18)
    ax[0].legend(frameon=False, fontsize=14), ax[1].legend(frameon=False, fontsize=14)
    
# print results
def return_results(model, test_ds, i="0"):
    # Evaluate model comparison
    test_batch, test_labels = next(iter(test_ds))
    loss, acc = model.evaluate(test_batch, test_labels, verbose=0)
    print("M{}|| Accuracy: {:.2f}% --- Loss: {:.2f}".format(i, 100 * acc, loss))

# %%
# print result summary 
return_results(model, test_ds)

# create a loss & accuracy subplot
f, ax = plt.subplots(figsize=(18, 7), ncols=2)

# plot results of each model
plot_model_results(history, "g", 1)
# Out:
# M0|| Accuracy: 86.00% --- Loss: 0.47

# %% [markdown]
# ## Self Influence
# #### Incorprating the self-influence code outlined in [TracIn paper](https://github.com/frederick0329/TracIn/blob/master/imagenet/resnet50_imagenet_self_influence.ipynb).

# %% [markdown]
# Method below calculations the self-influence (memorisation) score of a given training example for a given batch of images & labels and model checkpoints. Outputs from **run_self_influence** are concatenated into a dictionary using **memorisation_results** to simplify output. The indexing can be taken as the ID across each result member.

# %%
# method to calculate self-influence of batch members.
@tf.function
def run_self_influence(images, labels, models):
    self_influences = []
    for m in models:
        with tf.GradientTape(watch_accessed_variables=False) as tape:
            tape.watch(m.trainable_weights)
            probs = m(images)
            loss = tf.keras.losses.sparse_categorical_crossentropy(labels, probs)
        grads = tape.jacobian(loss, m.trainable_weights)
        scores = tf.add_n([tf.math.reduce_sum(
            grad * grad, axis=tf.range(1, tf.rank(grad), 1)) 
            for grad in grads])
        self_influences.append(scores)  

    # Using probs from last checkpoint
    probs, predicted_labels = tf.math.top_k(probs, k=1)
    return tf.math.reduce_sum(tf.stack(self_influences, axis=-1), axis=-1), labels, probs, predicted_labels

# method to concatenate all of the batch results together
def memorisation_results(memorisation, images, labels, probs, predicted_labels):
    result_dictionary = {
        "memorisation": np.array(np.concatenate(memorisation)),
        "images": np.concatenate(images),
        "labels": np.concatenate(labels),
        "probs": np.concatenate(probs),
        "predicted_labels": np.concatenate(predicted_labels)
    }
    return result_dictionary

# %% [markdown]
# This method incorprates **run_self_influence** and **memorisation_results** to return results for any given model scenario. It is used to study the comparisons between different CP memorisation scores.

# %%
def return_self_influence_results(train_ds_unshuffle, models):
    ds_memorisation = []
    ds_images = []
    ds_labels = []
    ds_probs = []
    ds_predicted_labels = []

    start = time.time()
    for images, labels in train_ds_unshuffle:
        memorisation_score, labels, probs, predictied_labels = run_self_influence(images, labels, models)
        ds_memorisation.append(memorisation_score)
        ds_images.append(images)
        ds_labels.append(labels)
        ds_probs.append(probs)
        ds_predicted_labels.append(predictied_labels)
    end = time.time()
    print("Total time:", datetime.timedelta(seconds=end - start))
    
    return memorisation_results(ds_memorisation, ds_images, ds_labels, ds_probs, ds_predicted_labels)

# %% [markdown]
# A method to load the desired model weights of a single or a list of epochs.

# %%
def return_models(epochs):
    loaded_models = []
    for epoch in epochs:
        path = "{}/cp_training_cifar_10/cp-00{:02d}.ckpt.index".format(os.getcwd(), epoch)
        if os.path.exists(path) == False:
            print ("File not found: cp-00{:02d}.ckpt.index".format(epoch))
        else:
            model = build_model()
            model.load_weights("cp_training_cifar_10/cp-00{:02d}.ckpt".format(epoch))
            loaded_models.append(model)
    return loaded_models

# %% [markdown]
# ### Experimentation

# %% [markdown]
# Load models from different epochs to calculate CP memorisation

# %%
# define multiple models for selected epochs to examine evolution of memorisation
full_cp = return_models([10, 20, 30, 40, 50])
model_10 = return_models([10])
model_20 = return_models([20])
model_30 = return_models([30])
model_40 = return_models([40])
model_50 = return_models([50])
model_60 = return_models([60])

# %%
# running experiments using full_cp list
results_full_cp = return_self_influence_results(train_ds_unshuffle, full_cp)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-3efa2ef8f4c0> in <module>
#       1 # running experiments using full_cp list
# ----> 2 results_full_cp = return_self_influence_results(train_ds_unshuffle, full_cp)
#
# <ipython-input-11-29e4b59baefd> in return_self_influence_results(train_ds_unshuffle, models)
#       8     start = time.time()
#       9     for images, labels in train_ds_unshuffle:
# ---> 10         memorisation_score, labels, probs, predictied_labels = run_self_influence(images, labels, models)
#      11         ds_memorisation.append(memorisation_score)
#      12         ds_images.append(images)
#
# /opt/anaconda/envs/Python3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# /opt/anaconda/envs/Python3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     812       # In this case we have not created variables on the first call. So we can
#     813       # run the first trace but we should fail if variables are created.
# --> 814       results = self._stateful_fn(*args, **kwds)
#     815       if self._created_variables:
#     816         raise ValueError("Creating variables on a non-first call to a function"
#
# /opt/anaconda/envs/Python3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# /opt/anaconda/envs/Python3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1841       `args` and `kwargs`.
#    1842     """
# -> 1843     return self._call_flat(
#    1844         [t for t in nest.flatten((args, kwargs), expand_composites=True)
#    1845          if isinstance(t, (ops.Tensor,
#
# /opt/anaconda/envs/Python3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1921         and executing_eagerly):
#    1922       # No tape is watching; skip to running the function.
# -> 1923       return self._build_call_outputs(self._inference_function.call(
#    1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#
# /opt/anaconda/envs/Python3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     543       with _InterpolateFunctionError(self):
#     544         if cancellation_manager is None:
# --> 545           outputs = execute.execute(
#     546               str(self.signature.name),
#     547               num_outputs=self._num_outputs,
#
# /opt/anaconda/envs/Python3/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# running experiments using specific epochs during training
results_epoch_10 = return_self_influence_results(train_ds_unshuffle, model_10)
results_epoch_20 = return_self_influence_results(train_ds_unshuffle, model_20)
results_epoch_30 = return_self_influence_results(train_ds_unshuffle, model_30)
results_epoch_40 = return_self_influence_results(train_ds_unshuffle, model_40)
results_epoch_50 = return_self_influence_results(train_ds_unshuffle, model_50)
results_epoch_60 = return_self_influence_results(train_ds_unshuffle, model_60)
# Out:
# Total time: 0:03:03.346295
# Total time: 0:03:03.487124
# Total time: 0:03:03.276059
# Total time: 0:03:02.485197
# Total time: 0:03:03.659614
# Total time: 0:03:02.525057

# %% [markdown]
# ### Analyse and visualise memorisation results

# %% [markdown]
# Running the self influence method over the entire training dataset in batches. The output for memorisation score, labels and probabilities are stored in lists specified.

# %%
# summery of results
print("Total examples with zero influence: {}".format(len([i for i in results_full_cp.get("memorisation") if i == 0])))

X = [i for i in results_full_cp.get("memorisation") if i != 0 and i < 20000]

# %% [markdown]
# ### Visualise results

# %%
# influence distribution
plt.figure(figsize=(10,5))
plt.hist(X, bins=100, alpha = 0.5)

#plt.xscale('log')
plt.gca().set(xlabel="$Self-influence$", ylabel="$Frequency$")

# %%
X = [i for i in results_epoch_50.get("memorisation") if i == 0]
len(X)

# %%
# apply cuts

#X_full = [i for i in results_full_cp.get("memorisation") if i > 1 and i < 20000]
X_10 = [i for i in results_epoch_10.get("memorisation") if i > 1 and i < 20000]
X_20 = [i for i in results_epoch_20.get("memorisation") if i > 1 and i < 20000]
X_30 = [i for i in results_epoch_30.get("memorisation") if i > 1 and i < 20000]
X_40 = [i for i in results_epoch_40.get("memorisation") if i > 1 and i < 20000]
X_50 = [i for i in results_epoch_50.get("memorisation") if i > 1 and i < 20000]
X_60 = [i for i in results_epoch_60.get("memorisation") if i > 1 and i < 20000]


# plot options
bins = 200
alpha = 0.7

# influence distribution of multiple models
plt.figure(figsize=(12,6))
#plt.hist(X_full, bins=bins, alpha=alpha, label="Full CP")
plt.hist(X_10, bins=bins, alpha=alpha, label="Epoch 10")
plt.hist(X_20, bins=bins, alpha=alpha, label="Epoch 20")
plt.hist(X_30, bins=bins, alpha=alpha, label="Epoch 30")
plt.hist(X_40, bins=bins, alpha=alpha, label="Epoch 40")
plt.hist(X_50, bins=bins, alpha=alpha, label="Epoch 50")
plt.legend(frameon=False, fontsize=14)
#plt.yscale('log')
#plt.xscale('log')
plt.gca().set(xlabel="$Self\ Influence$", ylabel="$Counts$")
# Out:
# [Text(0, 0.5, '$Counts$'), Text(0.5, 0, '$Self\\ Influence$')]
